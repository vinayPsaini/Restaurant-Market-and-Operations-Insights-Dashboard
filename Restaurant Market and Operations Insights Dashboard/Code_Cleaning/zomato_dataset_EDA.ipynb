# %%
import numpy as np
import pandas  as pd
import matplotlib as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/zomato.csv'
data = pd.read_csv(path, encoding='latin-1')

# %%
data.shape
# Out:
# (51717, 17)

# %%
with open('zomato.csv', 'r', encoding='latin-1') as f:
    lines = f.readlines()
print(lines[919])  # Python uses 0-based indexing
# Out:
# https://www.zomato.com/bangalore/kadala-tarangaa-banashankari-bangalore?context=,"27, 27th Cross, 1st Floor, Kadamba Complex, 2nd Stage, Banashankari, Bangalore",Kadala Tarangaa,Yes,No,3.6/5,129,"+91 9743491480

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data.drop(columns=['url', 'phone', 'dish_liked','reviews_list','menu_item'], inplace=True,errors='ignore')

# %%
data.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data['rate'] = data['rate'].astype(str).str.extract(r'(\d+\.\d+)')  # extract numeric part
data['rate'] = pd.to_numeric(data['rate'], errors='coerce')

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# rate                           10052
# approx_cost(for two people)      346
# rest_type                        227
# cuisines                          45
# location                          21
# online_order                       0
# name                               0
# address                            0
# book_table                         0
# votes                              0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
data.dtypes
# Out:
# address                         object
# name                            object
# online_order                    object
# book_table                      object
# rate                           float64
# votes                            int64
# location                        object
# rest_type                       object
# cuisines                        object
# approx_cost(for two people)     object
# listed_in(type)                 object
# listed_in(city)                 object
# dtype: object

# %%
data['rate'].value_counts(dropna=False).head(20)
# Out:
# rate
# NaN    10052
# 3.9     3972
# 3.8     3873
# 3.7     3821
# 3.6     3316
# 4.0     3183
# 4.1     2948
# 3.5     2784
# 3.4     2476
# 3.3     2310
# 4.2     2184
# 3.2     1873
# 4.3     1693
# 3.1     1561
# 4.4     1147
# 3.0     1023
# 2.9      802
# 4.5      656
# 2.8      600
# 2.7      307
# Name: count, dtype: int64

# %%
data['approx_cost(for two people)'].unique()[:20]
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000'], dtype=object)

# %%
data[data['approx_cost(for two people)'].isnull()].sample(5)
# Out:
#                                                  address  \
# 39171               127, NR Road, City Market, Bangalore
# 32551  6, Krishna Nagar Industrial Area, Behind Forum...
# 48022                  Metro Station, MG Road, Bangalore
# 38829  2nd Floor, 1 MG Mall, Trinity Circle, MG Road,...
# 37204  29/1, 30th Cross, 4th T Block, Thilknagar, Jay...
#
#                         name online_order book_table  rate  votes  \
# 39171   Al-Madina Restaurant           No         No   3.6     31
# 32551  Punjabi by Nature 2.0           No         No   4.2   3236
# 48022           Chef Baker's           No         No   NaN      0
# 38829           Mighty Small           No         No   4.1    259
# 37204            Tawa Sagara           No         No   3.8    122
#
#           location                    rest_type              cuisines  \
# 39171  City Market                Casual Dining                   NaN
# 32551          BTM  Casual Dining, Microbrewery          North Indian
# 48022      MG Road                Bakery, Kiosk      Bakery, Desserts
# 38829      MG Road           Casual Dining, Bar  Continental, Chinese
# 37204    Jayanagar                Casual Dining  Mangalorean, Seafood
#
#       approx_cost(for two people) listed_in(type)        listed_in(city)
# 39171                         NaN        Dine-out           Lavelle Road
# 32551                         NaN        Delivery  Koramangala 6th Block
# 48022                         NaN        Desserts         Residency Road
# 38829                         NaN        Dine-out           Lavelle Road
# 37204                         NaN        Dine-out  Koramangala 7th Block

# %%
data['approx_cost(for two people)'] = data['approx_cost(for two people)'].astype(str).str.replace(',', '')

# %%
data['approx_cost(for two people)'] = pd.to_numeric(data['approx_cost(for two people)'], errors='coerce')

# %%
data = data.dropna(subset=['rate', 'votes', 'approx_cost(for two people)', 'location', 'cuisines'])

# %%
data = data[(data['votes'] > 0) & (data['rate'] > 0)]

# %%
data.rename(columns={
    'name': 'Restaurant_Name',
    'online_order': 'Online_Order',
    'book_table': 'Table_Booking',
    'approx_cost(for two people)': 'Cost_For_Two',
    'listed_in(type)': 'Category',
    'listed_in(city)': 'City',
    'address': 'Address',
    'rate':'Rating',
    'votes':'Votes',
    'location': 'Location',
    'cuisines': 'Cuisines',
    'rest_type': 'Restaurant_Type'

}, inplace=True)

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.head()
# Out:
#                                              Address        Restaurant_Name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   Online_Order Table_Booking  Rating  Votes      Location  \
# 0          Yes           Yes     4.1    775  Banashankari
# 1          Yes            No     4.1    787  Banashankari
# 2          Yes            No     3.8    918  Banashankari
# 3           No            No     3.7     88  Banashankari
# 4           No            No     3.8    166  Basavanagudi
#
#        Restaurant_Type                        Cuisines  Cost_For_Two Category  \
# 0        Casual Dining  North Indian, Mughlai, Chinese         800.0   Buffet
# 1        Casual Dining     Chinese, North Indian, Thai         800.0   Buffet
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian         800.0   Buffet
# 3          Quick Bites      South Indian, North Indian         300.0   Buffet
# 4        Casual Dining        North Indian, Rajasthani         600.0   Buffet
#
#            City
# 0  Banashankari
# 1  Banashankari
# 2  Banashankari
# 3  Banashankari
# 4  Banashankari

# %%
data.dtypes
# Out:
# Address             object
# Restaurant_Name     object
# Online_Order        object
# Table_Booking       object
# Rating             float64
# Votes                int64
# Location            object
# Restaurant_Type     object
# Cuisines            object
# Cost_For_Two       float64
# Category            object
# City                object
# dtype: object

# %%
data.to_csv('Cleaned_Zomato.csv', index=False)

from google.colab import files
files.download('Cleaned_Zomato.csv')
